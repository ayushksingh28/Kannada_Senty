# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushksingh28/Kannada_Senty/blob/main/Kannada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.4 MB 5.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 44.6 MB/s
# ...
#      |████████████████████████████████| 101 kB 11.1 MB/s
# ...
#      |████████████████████████████████| 596 kB 70.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import pipeline
from transformers import AutoTokenizer, TFAutoModelForSequenceClassification
from transformers import DistilBertTokenizer, DistilBertModel, DistilBertConfig, TFAutoModelWithLMHead, TFAutoModel, AutoModel

from sklearn.model_selection import train_test_split

import tensorflow as tf

import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cbf6fcfb-9d78-4ca4-a79d-cf9470764cb9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cbf6fcfb-9d78-4ca4-a79d-cf9470764cb9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kan_text_444800.csv to kan_text_444800.csv
# Saving kan_text_445600.csv to kan_text_445600.csv
# Saving kan_text_446000.csv to kan_text_446000.csv
# Saving kan_text_446400.csv to kan_text_446400.csv
# Saving kan_text_446800.csv to kan_text_446800.csv
# Saving kan_text_447200.csv to kan_text_447200.csv
# Saving kan_text_447600.csv to kan_text_447600.csv
# Saving kan_text_448000.csv to kan_text_448000.csv
# Saving kan_text_448800.csv to kan_text_448800.csv
# Saving kan_text_449200.csv to kan_text_449200.csv
# ...

# %%
df0 = pd.read_csv("kan_text_444800.csv", header=None)
df1 = pd.read_csv("kan_text_445600.csv", header=None)
df2 = pd.read_csv("kan_text_446000.csv", header = None)
df3 = pd.read_csv("kan_text_446400.csv", header = None)
df4= pd.read_csv("kan_text_446800.csv", header=None)
df5 = pd.read_csv("kan_text_447200.csv", header = None)
df6 = pd.read_csv("kan_text_447600.csv", header = None)
df7 = pd.read_csv("kan_text_448000.csv", header = None)
df8 = pd.read_csv("kan_text_448800.csv", header = None)
df9 = pd.read_csv("kan_text_449200.csv", header = None)
df10 = pd.read_csv("kan_text_449600.csv", header = None)
df11 = pd.read_csv("kan_text_450000.csv", header = None)
df12 = pd.read_csv("kan_text_450400.csv", header = None)
df13 = pd.read_csv("kan_text_450800.csv", header = None)
df14 = pd.read_csv("kan_text_451200.csv", header = None)
df15 = pd.read_csv("kan_text_451600.csv", header = None)
df16 = pd.read_csv("kan_text_452000.csv", header = None)
df17 = pd.read_csv("kan_text_452400.csv", header = None)
df18 = pd.read_csv("kan_text_452800.csv", header = None)
df19 = pd.read_csv("kan_text_453200.csv", header = None)

# %%
df = pd.concat([df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df12,df13,df14,df15,df16,df17,df18,df19])
df
# Out:
#                                                      0  1
# 0    ಶಿಕ್ಷಣ ಕಾರ್ಯದರ್ಶಿ ಬೆಟ್ಸಿ ಡಿವೊಸ್ ಜೊತೆಗಿನ ಪ್ರಜಾಪ...  0
# 1    ಪೊಲೀಸರು ಮತ್ತು ಸ್ವಯಂಸೇವಕರು ಫೆಬ್ರವರಿ 27 ರ ಗುರುವಾ...  0
# 2    ಫೈಲ್ ಫೋಟೊ ರೋಮ್ನ ಹಳೆಯ ಭೂಗತ ಸಮಾಧಿ ಜಾಲಗಳೊಳಗಿನ ಕ್ಯ...  0
# 3    ಇಲ್ಲಿಯವರೆಗೆ ನೀವು ಎಸ್ ನಲ್ಲಿ ಕೆಲವೇ ಕೆಲವು ಪ್ರಕರಣಗ...  1
# 4    ಫೆಬ್ರವರಿ 27 ರಾಯಿಟರ್ಸ್ ಬಾಡೆನ್ ವುರ್ಟೆಂಬರ್ಗ್ನಲ್ಲಿ...  1
# ..                                                 ... ..
# 337  ಫೇಸ್ ಮಾಸ್ಕ್ಗಳು ​​ಮಾರಾಟವಾದವು ಮತ್ತು ವಿಮಾನ ನಿಲ್ದಾ...  0
# 338  ರೋಮ್ನಿಂದ ಅಲಿಟಲಿಯಾ ವಿಮಾನವನ್ನು ಸೋಮವಾರ ಮಾರಿಷಸ್ನಲ್...  0
# 339  ಬರ್ಬ್ಯಾಂಕ್ ಕ್ಯಾಲಿಫ್ ಬಿಸಿನೆಸ್ ವೈರ್ ಬಾಬ್ ಚಾಪೆಕ್ ...  1
# 340  ಡಬ್ಲ್ಯುಎಚ್‌ಒ ಸಿಡಿಸಿ ಮತ್ತು ಎಚ್‌ಎಸ್‌ಎಸ್ ಎಲ್ಲರೂ ಇ...  0
# 341  ಐಟಿಬಿಪಿ ಕ್ಯಾರೆಂಟೈನ್ ಫೆಸಿಲಿಟಿ ಫೈಲ್ ಫೋಟೋದಲ್ಲಿ ವು...  0
#
# [6948 rows x 2 columns]

# %%
from pandas import Series
from numpy.random import randn

# %%
df0.head()
# Out:
#                                                    0  1
# 0  ಶಿಕ್ಷಣ ಕಾರ್ಯದರ್ಶಿ ಬೆಟ್ಸಿ ಡಿವೊಸ್ ಜೊತೆಗಿನ ಪ್ರಜಾಪ...  0
# 1  ಪೊಲೀಸರು ಮತ್ತು ಸ್ವಯಂಸೇವಕರು ಫೆಬ್ರವರಿ 27 ರ ಗುರುವಾ...  0
# 2  ಫೈಲ್ ಫೋಟೊ ರೋಮ್ನ ಹಳೆಯ ಭೂಗತ ಸಮಾಧಿ ಜಾಲಗಳೊಳಗಿನ ಕ್ಯ...  0
# 3  ಇಲ್ಲಿಯವರೆಗೆ ನೀವು ಎಸ್ ನಲ್ಲಿ ಕೆಲವೇ ಕೆಲವು ಪ್ರಕರಣಗ...  1
# 4  ಫೆಬ್ರವರಿ 27 ರಾಯಿಟರ್ಸ್ ಬಾಡೆನ್ ವುರ್ಟೆಂಬರ್ಗ್ನಲ್ಲಿ...  1

# %%
df.head()
# Out:
#                                                    0  1
# 0  ಶಿಕ್ಷಣ ಕಾರ್ಯದರ್ಶಿ ಬೆಟ್ಸಿ ಡಿವೊಸ್ ಜೊತೆಗಿನ ಪ್ರಜಾಪ...  0
# 1  ಪೊಲೀಸರು ಮತ್ತು ಸ್ವಯಂಸೇವಕರು ಫೆಬ್ರವರಿ 27 ರ ಗುರುವಾ...  0
# 2  ಫೈಲ್ ಫೋಟೊ ರೋಮ್ನ ಹಳೆಯ ಭೂಗತ ಸಮಾಧಿ ಜಾಲಗಳೊಳಗಿನ ಕ್ಯ...  0
# 3  ಇಲ್ಲಿಯವರೆಗೆ ನೀವು ಎಸ್ ನಲ್ಲಿ ಕೆಲವೇ ಕೆಲವು ಪ್ರಕರಣಗ...  1
# 4  ಫೆಬ್ರವರಿ 27 ರಾಯಿಟರ್ಸ್ ಬಾಡೆನ್ ವುರ್ಟೆಂಬರ್ಗ್ನಲ್ಲಿ...  1

# %%
df.shape
# Out:
# (6948, 2)

# %%
from transformers import DistilBertTokenizer

# %%
tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %%
classifier = pipeline('sentiment-analysis')

import random
random.seed(42)
# Out:
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]

# %%
save_directory = "distilbert-base-uncased"
config = DistilBertConfig(dropout=0.2, attention_dropout=0.2)
config.output_hidden_states = False
transformer_model = TFAutoModel.from_pretrained(save_directory, from_pt=True, config = config)

input_ids_in = tf.keras.layers.Input(shape=(128,), name='input_token', dtype='int32')
input_masks_in = tf.keras.layers.Input(shape=(128,), name='masked_token', dtype='int32')
# Out:
# Downloading:   0%|          | 0.00/256M [00:00<?, ?B/s]
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFDistilBertModel: ['vocab_transform.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias']
# - This IS expected if you are initializing TFDistilBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFDistilBertModel were initialized from the PyTorch model.
# ...

# %%
embedding_layer = transformer_model(input_ids_in, attention_mask=input_masks_in)[0]
X = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(50, return_sequences=True, dropout=0.1, recurrent_dropout=0.1))(embedding_layer)
X = tf.keras.layers.GlobalMaxPool1D()(X)
X = tf.keras.layers.Dense(50, activation='relu')(X)
X = tf.keras.layers.Dropout(0.2)(X)
X = tf.keras.layers.Dense(1, activation='sigmoid')(X)
tf.keras.layers.Softmax(axis=-1)
model = tf.keras.Model(inputs=[input_ids_in, input_masks_in], outputs = X)

for layer in model.layers[:3]:
    layer.trainable = False
    
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=5e-6), loss=tf.keras.losses.BinaryCrossentropy(), metrics=["acc"])

# %%
inputs = tokenizer("df", return_tensors="tf")

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_token (InputLayer)       [(None, 128)]        0           []
#
#  masked_token (InputLayer)      [(None, 128)]        0           []
#
#  tf_distil_bert_model (TFDistil  TFBaseModelOutput(l  66362880   ['input_token[0][0]',
#  BertModel)                     ast_hidden_state=(N               'masked_token[0][0]']
#                                 one, 128, 768),
#                                  hidden_states=None
#                                 , attentions=None)
#
#  bidirectional (Bidirectional)  (None, 128, 100)     327600      ['tf_distil_bert_model[0][0]']
#
#  global_max_pooling1d (GlobalMa  (None, 100)         0           ['bidirectional[0][0]']
#  xPooling1D)
#
#  dense (Dense)                  (None, 50)           5050        ['global_max_pooling1d[0][0]']
#
# ...

# %%
from tensorflow.keras.utils import to_categorical

# %%
X_train, X_test, y_train, y_test = train_test_split(df[0], df[1], test_size=0.20, random_state=42)

# %%
X_train
# Out:
# 44     ಜೆನೆವಾ ದುಬೈ ರಾಯಿಟರ್ಸ್ ಯಾವುದೇ ದೇಶವು ಕರೋನವೈರಸ್ ಅ...
# 321    ನಿಮ್ಮ ಎಸ್‌ನಲ್ಲಿನ ಕೊರೊನಾವೈರಸ್ ಸಂಭವನೀಯ ಏಕಾಏಕಿ ಪ್...
# 234    ವೈರಸ್ ಹರಡುವಿಕೆಯ ಮಧ್ಯೆ ವ್ಯಾಪಕವಾದ ಬಜೆಟ್ ಕೊರತೆಯನ್...
# 310    ಮತ್ತೊಂದೆಡೆ, ಗೋಲ್ಡ್ಮನ್ ಮತ್ತೊಮ್ಮೆ ವಿಪರೀತ ಆಶಾವಾದಿ...
# 84     ಚಾರ್ಲ್‌ಸ್ಟನ್ ದಕ್ಷಿಣ ಕೆರೊಲಿನಾ ಸಿಎನ್‌ಎನ್ ಮ್ಯಾಸಚೂ...
#                              ...
# 164    ಕೊರೋನವೈರಸ್ ರಿಪ್ಸ್ ಕುರಿತು ಮಾತನಾಡಲು ಟ್ರಂಪ್ ವರದಿ ...
# 283    ಪ್ರತಿ ದೇಶವು ಕರೋನವೈರಸ್ ಪ್ರಕರಣಗಳಲ್ಲಿ ಹೆಚ್ಚಳವನ್ನು...
# 318    ಮುಂಬೈ ಜಿಡಿಪಿ ಬೆಳವಣಿಗೆಯು ಅಕ್ಟೋಬರ್ ಡಿಸೆಂಬರ್ 2019...
# 135    ಅಲ್ಜೀರಿಯಾ ಆಫ್ರಿಕಾದಲ್ಲಿ ಕರೋನವೈರಸ್ ಪ್ರಕರಣವನ್ನು ದ...
# 206    ಯುರೋಪಿನಲ್ಲಿನ ಕೊರೊನಾವೈರಸ್ನ ಹಠಾತ್ ಉಲ್ಬಣವು ಮಾರಣಾಂ...
# Name: 0, Length: 5558, dtype: object

# %%
X_train = tokenizer(
     list(X_train),
     padding=True,
     truncation=True,
     return_tensors="tf",
     max_length = 128
 )

X_test = tokenizer(
     list(X_test),
     padding=True,
     truncation=True,
     return_tensors="tf",
     max_length = 128
 )

# %%
trainin = model.fit([X_train["input_ids"],   X_train["attention_mask"]], 
          y_train,batch_size=128,epochs=8,verbose=1,validation_split = 0.3)
# Out:
# Epoch 1/8
# 31/31 [==============================] - 1293s 42s/step - loss: 0.6813 - acc: 0.5712 - val_loss: 0.6578 - val_acc: 0.6769
# Epoch 2/8
# 31/31 [==============================] - 1274s 41s/step - loss: 0.6516 - acc: 0.6537 - val_loss: 0.6392 - val_acc: 0.6781
# Epoch 3/8
# 31/31 [==============================] - 1276s 42s/step - loss: 0.6408 - acc: 0.6668 - val_loss: 0.6328 - val_acc: 0.6781
# Epoch 4/8
# 31/31 [==============================] - 1278s 42s/step - loss: 0.6368 - acc: 0.6710 - val_loss: 0.6306 - val_acc: 0.6781
# Epoch 5/8
# 31/31 [==============================] - 1289s 42s/step - loss: 0.6378 - acc: 0.6702 - val_loss: 0.6300 - val_acc: 0.6781
# Epoch 6/8
# 31/31 [==============================] - 1291s 42s/step - loss: 0.6384 - acc: 0.6702 - val_loss: 0.6298 - val_acc: 0.6781
# Epoch 7/8
# 31/31 [==============================] - 1292s 42s/step - loss: 0.6386 - acc: 0.6707 - val_loss: 0.6297 - val_acc: 0.6781
# Epoch 8/8
# ...
